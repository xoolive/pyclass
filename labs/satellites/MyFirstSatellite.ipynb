# %%
from vpython import canvas, sphere, vector, color, rate, mag2, norm
import math

# Right button drag or Ctrl-drag to rotate "camera" to view scene.
# To zoom, drag with middle button or Alt/Option depressed, or use scroll wheel.
#  On a two-button mouse, middle is left + right.

scene = canvas(title="MyFirstSatellite")

G = 6.7e-11
radiusEarth = 6.4e6
earth = sphere(
    pos=vector(0, 0, 0),
    radius=radiusEarth,
    color=color.blue,
    make_trail=True,
    trail_type="points",
    interval=10,
    retain=200,
)
earth.mass = 5.98e24

mu = earth.mass * G

altMEO = 20e6 + radiusEarth

satMEO = sphere(
    pos=vector(0, altMEO, 0),
    radius=1e6,
    color=color.yellow,
    make_trail=True,
    trail_type="points",
    interval=10,
    retain=200,
)
satMEO.mass = 1.0
satMEO.initSpeed = math.sqrt(G * earth.mass / altMEO)
satMEO.speed = vector(-satMEO.initSpeed, 0, 0)

altGEO = 36e6 + radiusEarth
satGEO = sphere(
    pos=vector(0, altGEO, 0),
    radius=1e6,
    color=color.green,
    make_trail=True,
    trail_type="points",
    interval=10,
    retain=200,
)
satGEO.mass = 1.0
satGEO.initSpeed = math.sqrt(G * earth.mass / altGEO)
satGEO.speed = vector(-satGEO.initSpeed, 0, 0)


altLEO = 163e3 + radiusEarth
satLEO = sphere(
    pos=vector(0, altLEO, 0),
    radius=1e6,
    color=color.orange,
    make_trail=True,
    trail_type="points",
    interval=10,
    retain=200,
)
satLEO.mass = 1.0
satLEO.initSpeed = math.sqrt(G * earth.mass / altLEO)
satLEO.speed = vector(-satLEO.initSpeed, 0, 0)

print("init speed " + str(satMEO.initSpeed) + " m/s")

# dt = 1e5
dt = 10

i = 0
imax = 1000
while i < imax:
    rate(100)
    satMEO.r = satMEO.pos - earth.pos

    # <satMEO.F> = m.g.<r>/||<r>||  = m.g.<norm(r)>
    # g = G.M/r^2
    # mu = G.M

    # <OM'> = <OM> + <dOM>
    # <dOM> = <v>*dt
    # <v> = <v> + <dv>
    # <dv> = <a>*dt
    # <a> = -m * (mu / ||<OM>||^3) * <OM>

    satMEO.F = -satMEO.mass * mu / (mag2(satMEO.r)) * norm(satMEO.r)
    satMEO.speed = satMEO.speed + satMEO.F / satMEO.mass * dt
    satMEO.pos = satMEO.pos + satMEO.speed * dt

    satGEO.r = earth.pos - satGEO.pos
    satGEO.F = satGEO.mass * mu / (mag2(satGEO.r)) * norm(satGEO.r)
    satGEO.speed = satGEO.speed + satGEO.F / satGEO.mass * dt
    satGEO.pos = satGEO.pos + satGEO.speed * dt

    satLEO.r = earth.pos - satLEO.pos
    satLEO.F = satLEO.mass * mu / (mag2(satLEO.r)) * norm(satLEO.r)
    satLEO.speed = satLEO.speed + satLEO.F / satLEO.mass * dt
    satLEO.pos = satLEO.pos + satLEO.speed * dt

    i += 1
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <IPython.core.display.HTML object>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <IPython.core.display.Javascript object>
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:13                                                                                   │
# │                                                                                                  │
# │    10                                                                                            │
# │    11 G = 6.7e-11                                                                                │
# │    12 radiusEarth = 6.4e6                                                                        │
# │ ❱  13 earth = sphere(                                                                            │
# │    14 │   pos=vector(0, 0, 0),                                                                   │
# │    15 │   radius=radiusEarth,                                                                    │
# │    16 │   color=color.blue,                                                                      │
# │                                                                                                  │
# │ /opt/mambaforge/envs/pyclass/lib/python3.11/site-packages/vpython/vpython.py:1172 in __init__    │
# │                                                                                                  │
# │   1169 │   def __init__(self, **args):                                                           │
# │   1170 │   │   args['_default_size'] = vector(2,2,2)                                             │
# │   1171 │   │   args['_objName'] = "sphere"                                                       │
# │ ❱ 1172 │   │   super(sphere, self).setup(args)                                                   │
# │   1173 │   │   self._sizing = False # no axis/size connection                                    │
# │   1174 │                                                                                         │
# │   1175 │   @property                                                                             │
# │                                                                                                  │
# │ /opt/mambaforge/envs/pyclass/lib/python3.11/site-packages/vpython/vpython.py:599 in setup        │
# │                                                                                                  │
# │    596 │   attrLists['ellipsoid'] = attrLists['sphere']                                          │
# │    597 │                                                                                         │
# │    598 │   def setup(self, args):                                                                │
# │ ❱  599 │   │   super(standardAttributes, self).__init__()                                        │
# │    600 │   │   self._constructing = True  ## calls to setters are from constructor               │
# │    601 │   │                                                                                     │
# │    602 │   │   objName = self._objName = args['_objName']  ## identifies object type             │
# │                                                                                                  │
# │ /opt/mambaforge/envs/pyclass/lib/python3.11/site-packages/vpython/vpython.py:257 in __init__     │
# │                                                                                                  │
# │    254 │   │   if not (baseObj._view_constructed or                                              │
# │    255 │   │   │   │   baseObj._canvas_constructing):                                            │
# │    256 │   │   │   if _isnotebook:                                                               │
# │ ❱  257 │   │   │   │   from .with_notebook import _                                              │
# │    258 │   │   │   else:                                                                         │
# │    259 │   │   │   │   from .no_notebook import _                                                │
# │    260 │   │   │   baseObj._view_constructed = True                                              │
# │                                                                                                  │
# │ /opt/mambaforge/envs/pyclass/lib/python3.11/site-packages/vpython/with_notebook.py:80 in         │
# │ <module>                                                                                         │
# │                                                                                                  │
# │    77 │   │   transfer = (v != __version__) # need not transfer files to nbextensions if corre   │
# │    78                                                                                            │
# │    79 if transfer:                                                                               │
# │ ❱  80 │   notebook.nbextensions.install_nbextension(path = package_dir+"/vpython_data",overwri   │
# │    81 │   notebook.nbextensions.install_nbextension(path = package_dir+"/vpython_libraries",ov   │
# │    82 │                                                                                          │
# │    83 │   # Wait for files to be transferred to nbextensions:                                    │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# AttributeError: module 'notebook' has no attribute 'nbextensions'
